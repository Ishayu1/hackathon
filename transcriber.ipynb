# %% [markdown]
# # Fast Military Audio Transcriber
#
# The reusable implementation lives in `transcriber.py`. This notebook is a quick demo surface for hackathon experiments.

# %%
# Run once if needed:
# %pip install faster-whisper

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from transcriber import classify_message

message = "Mayday, troops in contact, multiple casualties, need medevac now."
category, severity, score, terms = classify_message(message)
category, severity, score, terms

# %%
from transcriber import classify_message

custom_keywords_box = "raven, sector seven, bridge"
message = "Move to sector seven."
classify_message(message, custom_keywords=custom_keywords_box)

# %%
from transcriber import transcribe_audio

# Replace with your test file.
# result = transcribe_audio("audio.wav", model_size="distil-small.en", device="auto", compute_type="auto")
# result.category, result.severity, result.severity_score, result.transcript
